# %% [markdown]
# <a href="https://colab.research.google.com/github/ChinthalaLalitha/AIML_Project_and_Labs/blob/main/AIML_III_Module_4_project_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Students Internship Batch of 2024**
# ### Project for Module: Perceptron and Gradient Descent
#
# NOTE: YOU NEED TO WRITE CODE IN CELLS THAT SPECIFICALLY MENTION TASK-1, TASK-2, etc.
#
# WRITE ANY OBSERVATION(S), IF REQUIRED BY THE TASK, IN A SEPARATE CELL AT THE BOTTOM OF THE NOTEBOOK.
#
# ---

# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives
#
# Creating a function for the derivative of $f(x)$ called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
##########################
##########################

## TASK-1 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Gradient Descent
import numpy as np

# Define the function and its derivative
def f(x):
    return x**2  # Example function

def df(x):
    return 2*x  # Derivative of the function

# Initial parameters
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

# Lists to track x values and slopes
x_list = [new_x]
slope_list = [df(new_x)]

# Gradient descent loop
for n in range(500):
    previous_x = new_x
    gradient = df(new_x)  # Compute the gradient (slope)
    new_x = new_x - step_multiplier * gradient  # Update new_x
    step_size = abs(new_x - previous_x)  # Compute the step size

    x_list.append(new_x)
    slope_list.append(df(new_x))  # Append the new slope

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 50
# Local minimum occurs at: 3.425394462494306e-05
# Slope or df(x) value at this point is: 6.850788924988612e-05
# f(x) value or cost at this point is: 1.1733327223686654e-09

# %%
# Superimpose the gradient descent calculations on plot

plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)


plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
##########################
##########################

## TASK-2 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return  ## [REQUIRED]

def dg(x):
    return ## [REQUIRED]

    import numpy as np
import matplotlib.pyplot as plt

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return np.sin(x)  # Example: sine function

def dg(x):
    return np.cos(x)  # Derivative of sine is cosine

# Plot the function and its derivative
plt.figure(figsize=(10, 5))

# Plot g(x)
plt.subplot(1, 2, 1)
plt.plot(x_2, g(x_2), label="g(x) = sin(x)")
plt.title("Function g(x)")
plt.legend()

# Plot dg(x)
plt.subplot(1, 2, 2)
plt.plot(x_2, dg(x_2), label="g'(x) = cos(x)", color="orange")
plt.title("Derivative g'(x)")
plt.legend()

plt.show()

# %%
## TASK-3 : Plot function and derivative side by side like has been done earlier


import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

# Define the symbolic variable and function
x = sp.Symbol('x')
f = sp.sin(x)  # Example function

# Calculate the derivative
f_prime = sp.diff(f, x)

# Convert to numerical functions for plotting
f_lambdified = sp.lambdify(x, f, 'numpy')
f_prime_lambdified = sp.lambdify(x, f_prime, 'numpy')

# Generate x values
x_vals = np.linspace(-2*np.pi, 2*np.pi, 400)

# Evaluate the function and its derivative
y_vals = f_lambdified(x_vals)
y_prime_vals = f_prime_lambdified(x_vals)

# Create the plots
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plot the function
axs[0].plot(x_vals, y_vals, label=f'f(x) = {sp.latex(f)}')
axs[0].set_title('Function')
axs[0].legend()

# Plot the derivative
axs[1].plot(x_vals, y_prime_vals, label=f"f'(x) = {sp.latex(f_prime)}", color='orange')
axs[1].set_title('Derivative')
axs[1].legend()

# Display the plots
plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -1.522668191761128
# Number of steps: 212

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.5,
                                                 multiplier=0.01, precision=0.0001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -1.5125430525706185
# Number of steps: 301

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.1)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -1.521868468292447
# Number of steps: 180

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 0)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %%
## TASK-4 : code the same things as they were done for the first two examples

import sympy as sp

# Define the symbolic variable and function
x = sp.symbols('x')
f = x**2  # Example function

# Compute the symbolic derivative
df = sp.diff(f, x)

# Convert the symbolic derivative to a numerical function
df_func = sp.lambdify(x, df, 'numpy')

# Initial parameters
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

# Lists to track x values and slopes
x_list = [new_x]
slope_list = [df_func(new_x)]

# Gradient descent loop
for n in range(500):
    previous_x = new_x
    gradient = df_func(new_x)  # Compute the gradient (slope) using numerical function
    new_x = new_x - step_multiplier * gradient  # Update new_x
    step_size = abs(new_x - previous_x)  # Compute the step size

    x_list.append(new_x)
    slope_list.append(df_func(new_x))  # Append the new slope

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df_func(new_x))
print('f(x) value or cost at this point is:', f.evalf(subs={x: new_x}))
# Out:
# Loop ran this many times: 50
# Local minimum occurs at: 3.425394462494306e-05
# Slope or df(x) value at this point is: 6.850788924988612e-05
# f(x) value or cost at this point is: 1.17333272236867e-9

# %% [markdown]
# # Example 3 - Divergence and Overflow
#
# ## $$h(x) = x^5 - 2x^4 + 2$$

# %% [markdown]
# # The Learning Rate

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is: ', len(list_x))
# Out:
# Number of steps is:  276

# %%
## TASK-5 : Run gradient descent 3 times


import numpy as np
import matplotlib.pyplot as plt

# Define a simple quadratic cost function: J(theta) = theta^2
def cost_function(theta):
    return theta**2

# Define the gradient of the cost function
def gradient(theta):
    return 2 * theta

# Gradient descent algorithm
def gradient_descent(initial_theta, learning_rate, num_iterations):
    theta = initial_theta
    cost_history = []

    for i in range(num_iterations):
        cost = cost_function(theta)
        cost_history.append(cost)

        # Update theta
        theta = theta - learning_rate * gradient(theta)

    return cost_history

# Parameters for multiple runs
initial_thetas = [10, -5, 7]      # Different starting points
learning_rates = [0.1, 0.05, 0.2] # Different learning rates
num_iterations = 50               # Number of iterations

# Plotting the results of each run
plt.figure(figsize=(10, 6))

for i in range(3):
    initial_theta = initial_thetas[i]
    learning_rate = learning_rates[i]

    # Run gradient descent
    cost_history = gradient_descent(initial_theta, learning_rate, num_iterations)

    # Plot cost reduction for this run
    plt.plot(range(num_iterations), cost_history, label=f"Run {i+1}: θ0={initial_theta}, lr={learning_rate}")

# Plot settings
plt.title("Reduction in Cost Over Iterations (Multiple Runs)")
plt.xlabel("Iteration")
plt.ylabel("Cost")
plt.legend()
plt.show()

## TASK-6 :Plot two more learning rates: mid_gamma (0.001) and high_gamma (0.002)




# Define a simple quadratic cost function: J(theta) = theta^2
def cost_function(theta):
    return theta**2

# Define the gradient of the cost function
def gradient(theta):
    return 2 * theta

# Gradient descent algorithm
def gradient_descent(initial_theta, learning_rate, num_iterations):
    theta = initial_theta
    cost_history = []

    for i in range(num_iterations):
        cost = cost_function(theta)
        cost_history.append(cost)

        # Update theta
        theta = theta - learning_rate * gradient(theta)

    return cost_history

# Parameters for multiple runs
initial_theta = 10                # Same starting point for all runs
learning_rates = [0.1, 0.05, 0.2, 0.001, 0.002]  # Including mid_gamma and high_gamma
num_iterations = 50               # Number of iterations

# Plotting the results of each run
plt.figure(figsize=(10, 6))

for i, learning_rate in enumerate(learning_rates):

    # Run gradient descent
    cost_history = gradient_descent(initial_theta, learning_rate, num_iterations)

    # Plot cost reduction for this run
    plt.plot(range(num_iterations), cost_history, label=f"Run {i+1}: lr={learning_rate}")

# Plot settings
plt.title("Reduction in Cost Over Iterations (Multiple Learning Rates)")
plt.xlabel("Iteration")
plt.ylabel("Cost")
plt.legend()
plt.show()

n = 100
low_gamma = gradient_descent(derivative_func=dg, initial_guess= 3,
                                                multiplier=0.0005, precision=0.0001, max_iter=n)


mid_gamma =0.001 [REQUIRED]
high_gamma =0.002[REQUIRED]

# Experiment
insane_gamma = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.25, precision=0.0001, max_iter=n)
# Out:
# <>:109: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
# <>:110: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
# <>:109: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
# <>:110: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-89324b6f5dbd> in <cell line: 105>()
#     103
#     104 n = 100
# --> 105 low_gamma = gradient_descent(derivative_func=dg, initial_guess= 3,
#     106                                                 multiplier=0.0005, precision=0.0001, max_iter=n)
#     107
#
# TypeError: gradient_descent() got an unexpected keyword argument 'derivative_func'

# %%
## TASK-7 : Plot reduction in cost for each iteration

import numpy as np
import matplotlib.pyplot as plt

# Define a simple quadratic cost function: J(theta) = theta^2
def cost_function(theta):
    return theta**2

# Define the gradient of the cost function
def gradient(theta):
    return 2 * theta

# Gradient descent algorithm
def gradient_descent(initial_theta, learning_rate, num_iterations):
    theta = initial_theta
    cost_history = []

    for i in range(num_iterations):
        cost = cost_function(theta)
        cost_history.append(cost)

        # Update theta
        theta = theta - learning_rate * gradient(theta)

    return cost_history

# Parameters
initial_theta = 10  # Starting point
learning_rate = 0.1  # Step size
num_iterations = 50  # Number of iterations

# Run gradient descent
cost_history = gradient_descent(initial_theta, learning_rate, num_iterations)

# Plot cost reduction over iterations
plt.figure(figsize=(8, 6))
plt.plot(range(num_iterations), cost_history, label="Cost function")
plt.title("Reduction in Cost Over Iterations")
plt.xlabel("Iteration")
plt.ylabel("Cost")
plt.legend()
plt.show()

# %% [markdown]
# # Example 4 - Data Viz with 3D Charts
#
# ## Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
## TASK-8 : Code the same things as they were done for the first two examples

import numpy as np
import matplotlib.pyplot as plt

# Define a simple quadratic cost function: J(theta) = theta^2
def cost_function(theta):
    return theta**2

# Define the gradient of the cost function
def gradient(theta):
    return 2 * theta

# Gradient descent algorithm
def gradient_descent(initial_theta, learning_rate, num_iterations):
    theta = initial_theta
    cost_history = []

    for i in range(num_iterations):
        cost = cost_function(theta)
        cost_history.append(cost)

        # Update theta
        theta = theta - learning_rate * gradient(theta)

    return cost_history

# Parameters
initial_theta = 10                # Same starting point for all runs
learning_rates = [0.1, 0.05, 0.2, 0.001, 0.002]  # Including mid_gamma and high_gamma
num_iterations = 50               # Number of iterations

# Plotting the results of each run
plt.figure(figsize=(10, 6))

# Loop through the learning rates
for i, learning_rate in enumerate(learning_rates):

    # Run gradient descent for each learning rate
    cost_history = gradient_descent(initial_theta, learning_rate, num_iterations)

    # Plot cost reduction for this run
    plt.plot(range(num_iterations), cost_history, label=f"Run {i+1}: lr={learning_rate}")

# Plot settings
plt.title("Reduction in Cost Over Iterations (Multiple Learning Rates)")
plt.xlabel("Iteration")
plt.ylabel("Cost")
plt.legend()
plt.show()

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %%
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)

plt.show()


import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# Define the function f(x, y)
def f(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

# Generate x and y data
x_4 = np.linspace(-5, 5, 100)
y_4 = np.linspace(-5, 5, 100)
x_4, y_4 = np.meshgrid(x_4, y_4)

# Create the figure
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')

# Set labels
ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

# Plot the surface
ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)

# Show the plot
plt.show()

# %% [markdown]
# ##########################
# ##########################
#
# ## TASK-9 : Complete the lines of text wherever marked as [REQUIRED] in this cell.
#
# ##########################
# ##########################
#
# ## Partial Derivatives & Symbolic Computation
#
# ## $$\frac{\partial f}{\partial x} = ## [REQUIRED]
#
# ## $$\frac{\partial f}{\partial y} = ## [REQUIRED]
#
# ##########################
#
# ##########################
#
# Partial Derivatives & Symbolic Computation
# $$\frac{\partial f}{\partial x} = \lim_{\Delta x \to 0} \frac{f(x + \Delta x, y) - f(x, y)}{\Delta x}$$
# $$\frac{\partial f}{\partial y} = \lim_{\Delta y \to 0} \frac{f(x, y + \Delta y) - f(x, y)}{\Delta y}$$

# %%
import sympy as sp

# Define the symbolic variables
x, y = sp.symbols('x y')

# Define the cost function f(x, y)
f = x**2 + y**2  # Example function

# Print the function
print('Our cost function f(x, y) is: ', f)

# Compute and print partial derivatives
df_dx = sp.diff(f, x)  # Partial derivative wrt x
df_dy = sp.diff(f, y)  # Partial derivative wrt y
print('Partial derivative wrt x is: ', df_dx)
print('Partial derivative wrt y is: ', df_dy)

# Evaluate the function and derivatives at x=1.8, y=1.0
f_value = f.evalf(subs={x: 1.8, y: 1.0})
df_dx_value = df_dx.evalf(subs={x: 1.8, y: 1.0})
df_dy_value = df_dy.evalf(subs={x: 1.8, y: 1.0})

print('Value of f(x, y) at x=1.8, y=1.0 is: ', f_value)
print('Value of partial derivative wrt x: ', df_dx_value)
print('Value of partial derivative wrt y: ', df_dy_value)
# Out:
# Our cost function f(x, y) is:  x**2 + y**2
# Partial derivative wrt x is:  2*x
# Partial derivative wrt y is:  2*y
# Value of f(x, y) at x=1.8, y=1.0 is:  4.24000000000000
# Value of partial derivative wrt x:  3.60000000000000
# Value of partial derivative wrt y:  2.00000000000000

# %% [markdown]
# ## Batch Gradient Descent with SymPy

# %%
# Setup
import numpy as np
import sympy as sp

# Define the symbolic variables
a, b = sp.symbols('a b')

# Define the function f(a, b)
f = a**2 + b**2  # Example function

# Compute symbolic partial derivatives
df_da = sp.diff(f, a)
df_db = sp.diff(f, b)

# Convert symbolic expressions to functions
fpx = sp.lambdify((a, b), df_da, 'numpy')
fpy = sp.lambdify((a, b), df_db, 'numpy')

# Gradient descent parameters
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0])  # Initial guess

# Gradient descent loop
for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Define the function for cost calculation
def cost(x, y):
    return x**2 + y**2  # Same example function

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of:', params[0])
print('Minimum occurs at y value of:', params[1])
print('The cost is:', cost(params[0], params[1]))
# Out:
# Values in gradient array: [1.57835979e-48 8.76866553e-49]
# Minimum occurs at x value of: 6.313439179878134e-49
# Minimum occurs at y value of: 3.507466211043411e-49
# The cost is: 5.216183349963152e-97

# %%
##########################
##########################

## TASK-10 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Partial derivative functions example 4
def fpx(x, y):
    return ## [REQUIRED]

def fpy(x, y):
    return ## [REQUIRED]

# %%
# Setup
import numpy as np

# Define the function f(x, y)
def f(x, y):
    return x**2 + y**2  # Example function

# Partial derivative functions
def fpx(x, y):
    return 2 * x  # Partial derivative with respect to x

def fpy(x, y):
    return 2 * y  # Partial derivative with respect to y

# Gradient descent parameters
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0])  # Initial guess

# Gradient descent loop
for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of:', params[0])
print('Minimum occurs at y value of:', params[1])
print('The cost is:', f(params[0], params[1]))
# Out:
# Values in gradient array: [1.57835979e-48 8.76866553e-49]
# Minimum occurs at x value of: 6.313439179878134e-49
# Minimum occurs at y value of: 3.507466211043411e-49
# The cost is: 5.216183349963152e-97

# %% [markdown]
# ## Graphing 3D Gradient Descent

# %%
# Setup
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0]) # initial guess
values_array = params.reshape(1, 2)
print(values_array.shape)

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    #values_array = np.append(values_array, params.reshape(1, 2), axis=0)
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0)


# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# (1, 2)
# Values in gradient array [1.86728201e-19 1.03737889e-19]
# Minimum occurs at x value of:  7.469128023985783e-20
# Minimum occurs at y value of:  4.149515568880998e-20
# The cost is:  7.300635289507557e-39

# %%
# Generating 3D Plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)
ax.scatter(values_array[:, 0], values_array[:, 1],
           f(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()

# %% [markdown]
# ## For Reference, practice and play with the code below
#
# # Example 5 - Working with Data & a Real Cost Function
#
# ## Mean Squared Error: a cost function for regression problems
#
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (7, 1)
# Shape of y_5 array: (7, 1)

# %%
# Quick linear regressino
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# Theta 0: 0.8475351486029545
# Theta 1: 1.2227264637835913

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# Est values y_hat are:
#  [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
# In comparison, the actual y values are
#  [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE? Call the mse(y, y_hat)
# function and print out the MSE for the y_hat calculated above.

def mse(y, y_hat):
    #mse_calc = 1/7 * sum((y - y_hat)**2)
    #mse_calc = (1/y.size) * sum((y - y_hat)**2)
    mse_calc = np.average((y - y_hat)**2, axis=0)
    return mse_calc

# %%
print('Manually calculated MSE is:', mse(y_5, y_hat))
print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: [0.94796558]
# MSE regression using manual calc is 0.947965575979458
# MSE regression is 0.9479655759794577

# %% [markdown]
# ## 3D Plot for the MSE Cost Function
#
# ### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# ### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        #print(plot_t0[j][i])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-050b7bf9b7b1> in <cell line: 3>()
#       4     for j in range(nr_thetas):
#       5         #print(plot_t0[j][i])
# ----> 6         y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
#       7         plot_cost[i][j] = mse(y_5, y_hat)
#       8
#
# NameError: name 'x_5' is not defined

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(plot_cost.argmin(), plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[ij_min[0]][ij_min[1]])
print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[ij_min[0]][ij_min[1]])
# Out:
# Min value of plot_cost 0.0
# Min occurs at (i,j): (0, 0)
# Min MSE for Theta 0 at plot_t0[111][91] -1.0
# Min MSE for Theta 1 at plot_t1[111][91] -1.0

# %% [markdown]
# ## Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# ## MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size

    # Challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivs
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)

    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)

    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-9466cc92c6cf> in <cell line: 6>()
#       4 # Collect data points for scatter plot
#       5 plot_vals = thetas.reshape(1, 2)
# ----> 6 mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)
#       7
#       8 for i in range(1000):
#
# NameError: name 'mse' is not defined

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-50e119c4531a> in <cell line: 9>()
#       7 ax.set_zlabel('Cost - MSE', fontsize=20)
#       8
# ----> 9 ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
#      10 ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
#      11 plt.show()
#
# NameError: name 'mse_vals' is not defined
